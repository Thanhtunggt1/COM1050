# %%
#W2A1
print('Hello world!')
# Out:
# Hello world

# %%
#W2A2
name = input('Ten sinh vien ')
print(name)
# Out:
# Ten sinh vien Tran Thanh Tung
# Tran Thanh Tung

# %%
#W2A10
a = input('')
b = input('')
c = input('')
print("Hi " + c + ", " + b + " and " + a)
# Out:
# Tung
# Nghia
# An
# Hi An, Nghia and Tung

# %%
#W2A16
season = ['Spring', 'Summer', 'Autumn', 'Winter']
for i in season:
 print(i)
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
a='''  *
 ***
*****'''
print(a)
# Out:
#   *
#  ***
# *****

# %%
#W2A18
print('### # #  ### ### \n #  #  #  #  #\n #  #   # #  #\n #  #  #  #  # \n #  ##    #  #')
# Out:
# ### # #  ### ###
#  #  #  #  #  #
#  #  #   # #  #
#  #  #  #  #  #
#  #  ##    #  #

# %%
#W2A19
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September

# %%
#W2A21
for i in range(10):
 print('Hello, world')
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
